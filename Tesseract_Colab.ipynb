# %% [markdown]
# <a href="https://colab.research.google.com/github/vijjus/CV/blob/master/Tesseract_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! apt install tesseract-ocr
! apt install libtesseract-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libtesseract-dev is already the newest version (4.00~git2288-10f4998a-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.

# %%
# !pip install pytesseract

# %%
from glob import glob
import pytesseract
import matplotlib.pyplot as plt
from pytesseract import image_to_string
from PIL import Image

# %%
pytesseract.pytesseract.tesseract_cmd = r'/usr/local/bin/pytesseract'

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !cp /content/gdrive/MyDrive/bindata.tgz .
# !tar -zxf bindata.tgz
# !ls -l datagen/originals/ | wc -l
# !ls -l datagen/cleaned/ | wc -l
# Out:
# 1960
# 1959

# %%
# !pwd
# Out:
# /content

# %%
image_files = glob("/content/datagen/cleaned/*.png")
image_files[:5]
# Out:
# ['/content/datagen/cleaned/5a.1_cubanc_35_1_01281452ta_83.png',
#  '/content/datagen/cleaned/2a_cubanc_35_1_01281452ta_4.png',
#  '/content/datagen/cleaned/5.1_cubanc_35_1_01281452ta_58.png',
#  '/content/datagen/cleaned/5a.2_cubanc_35_1_01281452ta_68.png',
#  '/content/datagen/cleaned/1a_cubanc_35_1_01281452ta_63.png']

# %%
print(pytesseract.get_languages(config=''))
# Out:
# ['eng', 'osd']

# %%
for k in range(10):
  img = Image.open(image_files[k])
  plt.imshow(img, cmap='gray')
  plt.show()
  print(pytesseract.image_to_string(img, lang='eng'))
# Out:
# 9/24/42
# Kaywaoha, Torao
# h/31f/s2
# Student
# 2076 Ashby Ave. Berkeley, California
# Takeuchi, Ghokichi
# Central, Utah 9-7-£
